# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

source = '/content/drive/MyDrive/Dataset/Data'
if os.path.exists(source):
    print("Source directory exists.")
    print("Files in source directory:", os.listdir(source))
else:
    print("Source directory does not exist or is not accessible.")
# Out:
# Source directory exists.
# Files in source directory: ['valid', 'train', 'test', 'data.yaml']

# %%
import os

test_images_path = '/content/drive/MyDrive/Dataset/Data/test/images'
if os.path.exists(test_images_path):
    print("Directory exists. Files in the directory:")
    print(os.listdir(test_images_path))
else:
    print("Directory does not exist or is inaccessible.")
# Out:
# Directory exists. Files in the directory:
# ...

# %%
# showing lists in Data
import os
os.listdir('/content/drive/MyDrive/Dataset/Data')
# Out:
# ['valid', 'train', 'test', 'data.yaml']

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
data_yaml = """
train: /content/drive/MyDrive/Dataset/Data/train/images
val: /content/drive/MyDrive/Dataset/Data/valid/images
test: /content/drive/MyDrive/Dataset/Data/test/images

nc: 10  # Number of classes
names: ['Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone', 'Safety Vest', 'machinery', 'vehicle']
"""

# Save the data.yaml file
yaml_path = "/content/drive/MyDrive/Dataset/Data/data.yaml"  # Save it in Google Drive
with open(yaml_path, "w") as f:
    f.write(data_yaml)

# Verify it was saved
# !cat /content/drive/MyDrive/Dataset/Data/data.yaml
# Out:
# train: /content/drive/MyDrive/Dataset/Data/train/images
# val: /content/drive/MyDrive/Dataset/Data/valid/images
# test: /content/drive/MyDrive/Dataset/Data/test/images
#
# nc: 10  # Number of classes
# names: ['Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone', 'Safety Vest', 'machinery', 'vehicle']

# %%
from ultralytics import YOLO

# Load the YOLO model
model = YOLO('yolov8n.pt')  # Using the YOLOv8 nano model

# Corrected dataset path
data_yaml_path = "/content/drive/MyDrive/Dataset/Data/data.yaml"

# Train the model
model.train(data=data_yaml_path, epochs=2, imgsz=640, batch=8)
# Out:
# Ultralytics 8.3.156 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
pip install ultralytics opencv-python

# %%
print(model.names)
# Out:
# {0: 'Hardhat', 1: 'Mask', 2: 'NO-Hardhat', 3: 'NO-Mask', 4: 'NO-Safety Vest', 5: 'Person', 6: 'Safety Cone', 7: 'Safety Vest', 8: 'machinery', 9: 'vehicle'}

# %%
from flask import Flask, render_template, Response
import cv2
from ultralytics import YOLO

app = Flask(__name__)
model = YOLO("/content/drive/MyDrive/Dataset/YOLO_Training/yolov8_model/weights/best.pt")

@app.route('/')
def index():
    return render_template('index.html')

def gen_frames():
    cap = cv2.VideoCapture(0)
    while True:
        success, frame = cap.read()
        if not success:
            break
        else:
            results = model(frame)
            annotated_frame = results[0].plot()
            ret, buffer = cv2.imencode('.jpg', annotated_frame)
            frame_bytes = buffer.tobytes()
            yield (b'--frame\r\n'
                   b'Content-Type: image/jpeg\r\n\r\n' + frame_bytes + b'\r\n')

@app.route('/video')
def video():
    return Response(gen_frames(), mimetype='multipart/x-mixed-replace; boundary=frame')

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat

# %%
# import os

# # Define the test images path
# test_images_path = "/content/drive/MyDrive/Dataset/Data/test/images"

# # Get only 5 image files from the directory
# image_files = [os.path.join(test_images_path, f) for f in os.listdir(test_images_path) if f.endswith(('.jpg', '.png', '.jpeg'))][:5]

# # Run inference on the selected images
# for image_path in image_files:
#     results = model(image_path)
#     for result in results:
#         result.show()
# Out:
# image 1/1 /content/drive/MyDrive/Dataset/Data/test/images/000005_jpg.rf.96e9379ccae638140c4a90fc4b700a2b.jpg: 640x640 1 Hardhat, 7.5ms
# Speed: 2.1ms preprocess, 7.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# image 1/1 /content/drive/MyDrive/Dataset/Data/test/images/003357_jpg.rf.9867f91e88089bb68dc95947d5116d14.jpg: 640x640 1 Safety Cone, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# image 1/1 /content/drive/MyDrive/Dataset/Data/test/images/-4405-_png_jpg.rf.82b5c10b2acd1cfaa24259ada8e599fe.jpg: 640x640 (no detections), 7.5ms
# Speed: 2.1ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# ...

# %%
import cv2
import numpy as np

# %%
# from ultralytics import YOLO

# # Load the YOLO model (pretrained weights)
# model = YOLO("yolov8n.pt")  # YOLOv8 Nano model

# # Define the dataset path (your existing YAML file)
# data_yaml_path = "/content/drive/MyDrive/Dataset/Data/data.yaml"

# # Train the model and save outputs to the correct location
# model.train(
#     data=data_yaml_path,
#     epochs=2,          # Number of training epochs
#     imgsz=640,         # Image size
#     batch=8,
#     project="/content/drive/MyDrive/Dataset/YOLO_Training",  # Save inside Dataset folder
#     name="yolov8_model"  # Folder name for this run
# )
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
trained_model_path = "/content/drive/MyDrive/Dataset/YOLO_Training/yolov8_model/weights/best.pt"
model = YOLO(trained_model_path)

# %%
# from IPython.display import display, Javascript, Image
# from google.colab.output import eval_js
# from base64 import b64decode
# import cv2
# import numpy as np
# from ultralytics import YOLO

# # ✅ Load your trained YOLO model from Google Drive
# model_path = "/content/drive/MyDrive/Dataset/YOLO_Training/yolov8_model/weights/best.pt"
# model = YOLO(model_path)  # Use your trained model

# # ✅ Set detection thresholds
# confidence_threshold = 0.3  # Adjust based on performance
# iou_threshold = 0.4

# # JavaScript to start the camera and capture a frame
# start_camera_js = '''
#     let video;
#     let stream;
#     async function startCamera() {
#         const div = document.createElement('div');
#         const capture = document.createElement('button');
#         capture.textContent = 'Capture';
#         div.appendChild(capture);

#         video = document.createElement('video');
#         video.style.display = 'block';
#         stream = await navigator.mediaDevices.getUserMedia({video: true});

#         document.body.appendChild(div);
#         div.appendChild(video);
#         video.srcObject = stream;
#         await video.play();

#         google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

#         await new Promise((resolve) => capture.onclick = resolve);

#         const canvas = document.createElement('canvas');
#         canvas.width = video.videoWidth;
#         canvas.height = video.videoHeight;
#         canvas.getContext('2d').drawImage(video, 0, 0);
#         stream.getVideoTracks()[0].stop();
#         div.remove();
#         return canvas.toDataURL('image/jpeg', 0.8);
#     }
# '''

# # Display JavaScript for the camera
# display(Javascript(start_camera_js))

# def take_photo(filename='photo.jpg'):
#     """Capture a photo using the webcam."""
#     data = eval_js('startCamera()')
#     binary = b64decode(data.split(',')[1])
#     with open(filename, 'wb') as f:
#         f.write(binary)
#     return filename

# def process_frame(frame):
#     """Perform YOLO inference on the captured frame."""
#     results = model(frame, conf=confidence_threshold, iou=iou_threshold)

#     # Get the annotated image
#     annotated_frame = results[0].plot()

#     # Display the detected image
#     display(Image(data=cv2.imencode('.jpg', annotated_frame)[1].tobytes()))

# # ✅ Main execution
# try:
#     # Capture an image from the webcam
#     filename = take_photo()
#     frame = cv2.imread(filename)

#     # Run PPE detection
#     process_frame(frame)

# except KeyboardInterrupt:
#     print("Stopped.")
# Out:
# 0: 480x640 (no detections), 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
# from IPython.display import display, Javascript, Image
# from google.colab.output import eval_js
# from base64 import b64decode
# import cv2
# import numpy as np
# from ultralytics import YOLO

# # ✅ Load your trained YOLO model from Google Drive
# model_path = "/content/drive/MyDrive/Dataset/YOLO_Training/yolov8_model/weights/best.pt"
# model = YOLO(model_path)  # Load your trained model

# # ✅ Print class names to ensure 'Person' is included
# print("🔍 Model Classes:", model.names)

# # ✅ Set detection thresholds
# confidence_threshold = 0.1  # Lowered to detect more objects
# iou_threshold = 0.3

# # JavaScript for starting camera and capturing a frame
# start_camera_js = '''
#     let video;
#     let stream;
#     async function startCamera() {
#         const div = document.createElement('div');
#         const capture = document.createElement('button');
#         capture.textContent = 'Capture';
#         div.appendChild(capture);

#         video = document.createElement('video');
#         video.style.display = 'block';
#         stream = await navigator.mediaDevices.getUserMedia({video: true});

#         document.body.appendChild(div);
#         div.appendChild(video);
#         video.srcObject = stream;
#         await video.play();

#         google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

#         await new Promise((resolve) => capture.onclick = resolve);

#         const canvas = document.createElement('canvas');
#         canvas.width = video.videoWidth;
#         canvas.height = video.videoHeight;
#         canvas.getContext('2d').drawImage(video, 0, 0);
#         stream.getVideoTracks()[0].stop();
#         div.remove();
#         return canvas.toDataURL('image/jpeg', 0.8);
#     }
# '''

# # Display JavaScript for camera
# display(Javascript(start_camera_js))

# def take_photo(filename='photo.jpg'):
#     """Capture a photo using the webcam."""
#     data = eval_js('startCamera()')
#     binary = b64decode(data.split(',')[1])
#     with open(filename, 'wb') as f:
#         f.write(binary)
#     return filename

# def process_frame(frame):
#     """Perform YOLO inference and display detected objects."""
#     results = model(frame, conf=confidence_threshold, iou=iou_threshold)

#     # Extract bounding box details
#     boxes = results[0].boxes.xyxy.cpu().numpy() if results[0].boxes else []
#     confidences = results[0].boxes.conf.cpu().numpy() if results[0].boxes else []
#     class_ids = results[0].boxes.cls.cpu().numpy().astype(int) if results[0].boxes else []
#     class_names = model.names  # Get class names

#     detected_objects = []

#     for box, conf, cls_id in zip(boxes, confidences, class_ids):
#         label = class_names.get(cls_id, "Unknown")  # Get class name
#         detected_objects.append(f"{label} ({conf:.2f})")

#     # ✅ Print all detected objects
#     print(f"🟢 Detected objects: {', '.join(detected_objects) if detected_objects else 'None'}")

#     # Annotate the image with detections
#     annotated_frame = results[0].plot()

#     # Display the detected image
#     display(Image(data=cv2.imencode('.jpg', annotated_frame)[1].tobytes()))

# # ✅ Main execution
# try:
#     while True:
#         input("Press Enter to capture an image...")

#         # Capture an image from the webcam
#         filename = take_photo()
#         frame = cv2.imread(filename)

#         # Run PPE detection
#         process_frame(frame)

#         # Ask if the user wants to continue
#         cont = input("📸 Capture another image? (y/n): ")
#         if cont.lower() != 'y':
#             print("📴 Stopping camera capture.")
#             break

# except KeyboardInterrupt:
#     print("Stopped.")
# Out:
# 🔍 Model Classes: {0: 'Hardhat', 1: 'Mask', 2: 'NO-Hardhat', 3: 'NO-Mask', 4: 'NO-Safety Vest', 5: 'Person', 6: 'Safety Cone', 7: 'Safety Vest', 8: 'machinery', 9: 'vehicle'}
# Press Enter to capture an image...2
#
# 0: 480x640 1 NO-Hardhat, 1 Person, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 🟢 Detected objects: NO-Hardhat (0.36), Person (0.10)
# 📸 Capture another image? (y/n): n
# 📴 Stopping camera capture.
